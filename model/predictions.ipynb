# %%
import pandas as pd

# %%
df = pd.read_csv('../data/master_campus_demand_W1_to_W16.csv')
df.head()
# Out:
#    Week     Day  Hour          Building  Demand_Prediction  \
# 0     1  Monday     0  Grainger Library                0.0
# 1     1  Monday     0      Funk Library                0.0
# 2     1  Monday     0      Main Library               -1.0
# 3     1  Monday     0      Illini Union               -1.0
# 4     1  Monday     0               CIF               -1.0
#
#    Pressure_Multiplier  Timestep
# 0                  1.0         0
# 1                  1.0         0
# 2                  1.0         0
# 3                  1.0         0
# 4                  1.0         0

# %%
# Monday, 7 pm 
df[(df['Week'] == 3) & (df['Day'] == 'Monday') & (df['Hour'] == 19)]
# Out:
#       Week     Day  Hour                  Building  Demand_Prediction  \
# 2840     3  Monday    19          Grainger Library              0.401
# 2841     3  Monday    19              Funk Library              0.115
# 2842     3  Monday    19              Main Library              0.286
# 2843     3  Monday    19              Illini Union              0.696
# 2844     3  Monday    19                       CIF              0.354
# 2845     3  Monday    19                       BIF              0.229
# 2846     3  Monday    19      Siebel Center for CS              0.229
# 2847     3  Monday    19  Siebel Center for Design              0.073
#
#       Pressure_Multiplier  Timestep
# 2840                1.133       355
# 2841                1.133       355
# 2842                1.133       355
# 2843                1.133       355
# 2844                1.133       355
# 2845                1.133       355
# 2846                1.133       355
# 2847                1.133       355

# %%
# [Week], [Day], [Time]
df[(df['Week'] == 8) & (df['Day'] == 'Saturday') & (df['Hour'] == 14)]
# Out:
#        Week       Day  Hour                  Building  Demand_Prediction  \
# 10480     8  Saturday    14          Grainger Library              0.392
# 10481     8  Saturday    14              Funk Library              0.300
# 10482     8  Saturday    14              Main Library              0.210
# 10483     8  Saturday    14              Illini Union              0.273
# 10484     8  Saturday    14                       CIF              0.346
# 10485     8  Saturday    14                       BIF              0.168
# 10486     8  Saturday    14      Siebel Center for CS              0.224
# 10487     8  Saturday    14  Siebel Center for Design              0.191
#
#        Pressure_Multiplier  Timestep
# 10480                  1.0      1310
# 10481                  1.0      1310
# 10482                  1.0      1310
# 10483                  1.0      1310
# 10484                  1.0      1310
# 10485                  1.0      1310
# 10486                  1.0      1310
# ...

# %% [markdown]
# ## Calendar

# %%
# [Week], [Day], [Time]
df[(df['Week'] == 12) & (df['Day'] == 'Wednesday') & (df['Hour'] == 11)]
# Out:
#        Week     Day  Hour                  Building  Demand_Prediction  \
# 14872    12  Monday    11          Grainger Library              0.505
# 14873    12  Monday    11              Funk Library              0.858
# 14874    12  Monday    11              Main Library              0.692
# 14875    12  Monday    11              Illini Union              0.945
# 14876    12  Monday    11                       CIF              0.446
# 14877    12  Monday    11                       BIF              0.554
# 14878    12  Monday    11      Siebel Center for CS              0.289
# 14879    12  Monday    11  Siebel Center for Design              0.546
#
#        Pressure_Multiplier  Timestep
# 14872                1.428      1859
# 14873                1.428      1859
# 14874                1.428      1859
# 14875                1.428      1859
# 14876                1.428      1859
# 14877                1.428      1859
# 14878                1.428      1859
# ...

# %%
# [Week], [Day], [Time]
df[(df['Week'] == 16) & (df['Day'] == 'Tuesday') & (df['Hour'] == 15)]
# Out:
#        Week      Day  Hour                  Building  Demand_Prediction  \
# 20472    16  Tuesday    15          Grainger Library              1.000
# 20473    16  Tuesday    15              Funk Library              1.000
# 20474    16  Tuesday    15              Main Library              1.000
# 20475    16  Tuesday    15              Illini Union              0.645
# 20476    16  Tuesday    15                       CIF              0.975
# 20477    16  Tuesday    15                       BIF              0.868
# 20478    16  Tuesday    15      Siebel Center for CS              0.629
# 20479    16  Tuesday    15  Siebel Center for Design              0.729
#
#        Pressure_Multiplier  Timestep
# 20472                  1.6      2559
# 20473                  1.6      2559
# 20474                  1.6      2559
# 20475                  1.6      2559
# 20476                  1.6      2559
# 20477                  1.6      2559
# 20478                  1.6      2559
# ...
